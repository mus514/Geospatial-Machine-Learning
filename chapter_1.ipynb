# %%
import pandas as pd
import geopandas as gpd
import rasterio
# from rasterio.plot import show

# %%
gdf = gpd.read_file('data/chapter_1/ne_10m_admin_0_countries_mar.shp')

# %%
gdf[gdf['SOVEREIGNT'] == 'Morocco'].plot()
# Out:
# <Axes: >

# %%
gdf = gpd.read_file('data/chapter_1/sample.json')

# %%
gdf.geometry
# Out:
# 0                            POINT (102.00000 0.50000)
# 1    LINESTRING (102.00000 0.00000, 103.00000 1.000...
# 2    POLYGON ((100.00000 0.00000, 101.00000 0.00000...
# Name: geometry, dtype: geometry

# %%
img = rasterio.open('data/chapter_1/NE1_HR_LC_SR.tif')

# %%
rasterio.plot.show(img)
# Out:
# <Axes: >
