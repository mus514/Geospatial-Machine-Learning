# %%
import pandas as pd
import geopandas as gpd
import fiona
import matplotlib.pyplot as plt
# from rasterio.plot import show

# %%
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
kmlfile = gpd.read_file('data/chapter_2/france.kml')

# %%
print(kmlfile)
# Out:
#      Name Description                                           geometry
# 0  France              POLYGON Z ((2.64073 51.03817 0.00000, -4.96181...

# %%
print(kmlfile.loc[0, 'geometry'])
# Out:
# POLYGON Z ((2.6407314 51.0381664 0, -4.9618076 48.6149919 0, -1.8856358 43.353406 0, 0.4214931 42.2572503 0, 7.8482509 43.1293152 0, 8.3975674 49.092091 0, 2.6407314 51.0381664 0))

# %%
kmlfile.plot()
plt.title('Map in WGS 84')
# Out:
# Text(0.5, 1.0, 'Map in WGS 84')

# %%
proj_kml = kmlfile.to_crs('ESRI:102014')
proj_kml
# Out:
#      Name Description                                           geometry
# 0  France              POLYGON Z ((-508366.619 2391718.005 0.000, -10...

# %%
proj_kml.plot()
plt.title('ESRI:102014 map')
# Out:
# Text(0.5, 1.0, 'ESRI:102014 map')
